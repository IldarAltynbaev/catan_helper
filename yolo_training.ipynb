# %%
import numpy as np 
import pandas as pd 
import os
import zipfile
import shutil 
from tqdm import tqdm
import torch
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import time
import copy
import random
from PIL import Image


from torchvision import transforms, models
from torchvision.transforms import functional
from torch.utils.data import ConcatDataset
from matplotlib.animation import FuncAnimation
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.5/870.5 kB 20.8 MB/s eta 0:00:0000:01
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
os.makedirs('images/train')
os.makedirs('images/val')
os.makedirs('labels/train')
os.makedirs('labels/val')

for file in os.listdir('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/images/train'):
        file_name = os.fsdecode(file)
        if (file.endswith(".png")):  
            shutil.copy(os.path.join('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/images/train', file_name), 
                        os.path.join('/kaggle/working/images/train', file_name))
            
for file in os.listdir('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/images/val'):
        file_name = os.fsdecode(file)
        if (file.endswith(".png")):  
            shutil.copy(os.path.join('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/images/val', file_name), 
                        os.path.join('/kaggle/working/images/val', file_name))
            
for file in os.listdir('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/labels/train'):
        file_name = os.fsdecode(file)
        if (file.endswith(".txt")):  
            shutil.copy(os.path.join('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/labels/train', file_name), 
                        os.path.join('/kaggle/working/labels/train', file_name))
           
for file in os.listdir('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/labels/val'):
        file_name = os.fsdecode(file)
        if (file.endswith(".txt")):  
            shutil.copy(os.path.join('/kaggle/input/catan-dataset/catan_train_dataset/catan_train_dataset/labels/val', file_name), 
                        os.path.join('/kaggle/working/labels/val', file_name))

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 93.8MB/s]

# %%
results = model.train(data="/kaggle/input/catan-dataset/yolo_config.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
